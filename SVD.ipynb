# %% [markdown]
# <a href="https://colab.research.google.com/github/zeolacode/PDSA/blob/main/SVD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RECONSTRUÇÃO DE IMAGEM USANDO DECOMPOSIÇÃO DE VALOR SINGULAR (SVD) EM PYTHON
#
# Decomposição de valor singular, também conhecida como SVD, é uma das muitas técnicas de decomposição de array que decompõe uma array em 3 subarrayes, a saber U, S, V, onde U é o autovetor esquerdo, S é uma array diagonal de valores singulares e V é chamado de autovetor direito. Podemos reconstruir SVD de uma imagem usando o método linalg.svd() do módulo NumPy.

# %% [markdown]
# linalg.svd (array, full_matrices = True, compute_uv = True, hermitian = False)
#
# Parâmetros:
#
# array: uma array real ou complexa de tamanho> 2.
# full_matrices: Se True, o tamanho das arrayes uev são mxn, se False então a forma das arrayes uev são mxk, onde k é apenas valores diferentes de zero.
# compute_uv: obtém o valor booleano para calcular as arrayes uev junto com a array s.
# Hermitian: Por padrão, a array é assumida como Hermitian se ela contiver valores reais, isso é usado internamente para calcular eficientemente os valores singulares.

# %%
# import module
import requests
import cv2
import numpy as np
import matplotlib.pyplot as plt
 
# assign and open image
url = 'https://media.geeksforgeeks.org/wp-content/cdn-uploads/20210401173418/Webp-compressed.jpg'
response = requests.get(url, stream=True)
 
with open('image.png', 'wb') as f:
    f.write(response.content)
 
img = cv2.imread('image.png')
 
# Converting the image into gray scale for faster
# computation.
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
 
# Calculating the SVD
u, s, v = np.linalg.svd(gray_image, full_matrices=False)
 
# inspect shapes of the matrices
print(f'u.shape:{u.shape},s.shape:{s.shape},v.shape:{v.shape}')
# Out:
# u.shape:(3648, 3648),s.shape:(3648,),v.shape:(3648, 5472)

# %% [markdown]
# A saída acima indica que existem 3648 autovetores linearmente independentes nesta imagem.

# %% [markdown]
# Agora, vejamos a variação da imagem usada em um vetor singular graficamente:

# %%
# import module
import seaborn as sns
 
var_explained = np.round(s**2/np.sum(s**2), decimals=6)
 
# Variance explained top Singular vectors
print(f'variance Explained by Top 20 singular values:\n{var_explained[0:20]}')
 
sns.barplot(x=list(range(1, 21)),
            y=var_explained[0:20], color="dodgerblue")
 
plt.title('Variance Explained Graph')
plt.xlabel('Singular Vector', fontsize=16)
plt.ylabel('Variance Explained', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# variance Explained by Top 20 singular values:
# [9.9795e-01 7.4000e-04 3.8900e-04 3.0500e-04 1.0600e-04 7.4000e-05
#  5.7000e-05 3.9000e-05 3.1000e-05 2.6000e-05 2.2000e-05 1.9000e-05
#  1.5000e-05 1.4000e-05 1.1000e-05 9.0000e-06 9.0000e-06 7.0000e-06
#  7.0000e-06 6.0000e-06]

# %% [markdown]
# O Gráfico da Variância acima mostra claramente que cerca de 99,77% das informações são explicadas pelo primeiro autovetor e seus próprios autovalores correspondentes. Portanto, é muito aconselhável reconstruir a imagem apenas com os poucos autovetores próprios.

# %%
# plot images with different number of components
comps = [3648, 1, 5, 10, 15, 20]
plt.figure(figsize=(12, 6))
 
for i in range(len(comps)):
    low_rank = u[:, :comps[i]] @ np.diag(s[:comps[i]]) @ v[:comps[i], :]
     
    if(i == 0):
        plt.subplot(2, 3, i+1),
        plt.imshow(low_rank, cmap='gray'),
        plt.title(f'Actual Image with n_components = {comps[i]}')
     
    else:
        plt.subplot(2, 3, i+1),
        plt.imshow(low_rank, cmap='gray'),
        plt.title(f'n_components = {comps[i]}')

# %% [markdown]
# Explicação:
#
# - Embora o primeiro vetor próprio contenha 99,77% das informações, reconstruir uma imagem apenas a partir dele não fornece uma imagem clara.
# - Usar os 15 vetores principais para a reconstrução da imagem fornece uma aproximação boa o suficiente. Também fora de 3648 vetores que é uma diminuição maciça na computação e também comprime a imagem.
